# %% [raw]
# ---
# title: "UFC Analysis"
# author:
#    -Chance
#    -Solange
#    -Hope
# format:
#   html:
#     code-fold: true
# jupyter: python3
# execute:
#   eval: true
#   echo: true
#   warning: false
#   message: false
# ---

# %% [markdown]
# ### Load Dataset and Visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML
import re

# %%
#| echo: true
#| output: true

df = pd.read_csv(r"C:\Users\USER\Downloads\ufc_clean_no_duplicates.csv")
HTML(df.head(10).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Fighter</th>
#       <th>W/L</th>
#       <th>Opponent</th>
#       <th>Knockdowns</th>
#       <th>Strikes</th>
#       <th>Takedowns</th>
#       <th>SubmissionAttempts</th>
#       <th>Event</th>
#       <th>Method</th>
#       <th>Round</th>
#       <th>Date</th>
#       <th>First Name</th>
#       <th>Last Name</th>
#       <th>Link</th>
#       <th>Nick Name</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th>Draws</th>
#       <th>Height</th>
#       <th>Weight</th>
#       <th>Reach</th>
#       <th>STANCE</th>
#       <th>DOB</th>
#       <th>SLpM</th>
#       <th>Str. Acc.</th>
#       <th>SApM</th>
#       <th>Str. Def</th>
#       <th>TD Avg.</th>
#       <th>TD Acc.</th>
#       <th>TD Def.</th>
#       <th>Sub. Avg.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>tom aaron</td>
#       <td>loss</td>
#       <td>Matt Ricehouse</td>
#       <td>--</td>
#       <td>--</td>
#       <td>--</td>
#       <td>--</td>
#       <td>Strikeforce - Henderson vs. Babalu                                   Dec. 04, 2010</td>
#       <td>U-DEC</td>
#       <td>3.0</td>
#       <td>7/12/2005</td>
#       <td>Tom</td>
#       <td>Aaron</td>
#       <td>http://ufcstats.com/fighter-details/93fe7332d16c6ad9</td>
#       <td>NaN</td>
#       <td>5.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>--</td>
#       <td>155 lbs.</td>
#       <td>--</td>
#       <td>NaN</td>
#       <td>7/13/1978</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>tom aaron</td>
#       <td>win</td>
#       <td>Eric Steenberg</td>
#       <td>--</td>
#       <td>--</td>
#       <td>--</td>
#       <td>--</td>
#       <td>Strikeforce - Heavy Artillery                                   May. 15, 2010</td>
#       <td>SUB</td>
#       <td>1.0</td>
#       <td>7/15/2009</td>
#       <td>Tom</td>
#       <td>Aaron</td>
#       <td>http://ufcstats.com/fighter-details/93fe7332d16c6ad9</td>
#       <td>NaN</td>
#       <td>5.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>--</td>
#       <td>155 lbs.</td>
#       <td>--</td>
#       <td>NaN</td>
#       <td>7/13/1978</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>0%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>danny abbadi</td>
#       <td>loss</td>
#       <td>Jorge Gurgel</td>
#       <td>0</td>
#       <td>56</td>
#       <td>0</td>
#       <td>0</td>
#       <td>UFC 63: Hughes vs Penn                                   Sep. 23, 2006</td>
#       <td>S-DEC</td>
#       <td>3.0</td>
#       <td>1/1/1999</td>
#       <td>Danny</td>
#       <td>Abbadi</td>
#       <td>http://ufcstats.com/fighter-details/15df64c02b6b0fde</td>
#       <td>The Assassin</td>
#       <td>4.0</td>
#       <td>6.0</td>
#       <td>0</td>
#       <td>5' 11"</td>
#       <td>155 lbs.</td>
#       <td>--</td>
#       <td>Orthodox</td>
#       <td>7/3/1983</td>
#       <td>3.29</td>
#       <td>38%</td>
#       <td>4.41</td>
#       <td>57%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>77%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>danny abbadi</td>
#       <td>loss</td>
#       <td>Kalib Starnes</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>The Ultimate Fighter: Team Ortiz vs. Team Shamrock Finale                                   Jun. 24, 2006</td>
#       <td>SUB</td>
#       <td>1.0</td>
#       <td>1/1/2012</td>
#       <td>Danny</td>
#       <td>Abbadi</td>
#       <td>http://ufcstats.com/fighter-details/15df64c02b6b0fde</td>
#       <td>The Assassin</td>
#       <td>4.0</td>
#       <td>6.0</td>
#       <td>0</td>
#       <td>5' 11"</td>
#       <td>155 lbs.</td>
#       <td>--</td>
#       <td>Orthodox</td>
#       <td>7/3/1983</td>
#       <td>3.29</td>
#       <td>38%</td>
#       <td>4.41</td>
#       <td>57%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>77%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>nariman abbasov</td>
#       <td>loss</td>
#       <td>Ismael Bonfim</td>
#       <td>0</td>
#       <td>45</td>
#       <td>0</td>
#       <td>0</td>
#       <td>DWCS 6.7                                   Sep. 06, 2022</td>
#       <td>U-DEC</td>
#       <td>3.0</td>
#       <td>1/1/2012</td>
#       <td>Nariman</td>
#       <td>Abbasov</td>
#       <td>http://ufcstats.com/fighter-details/59a9d6dac61c2540</td>
#       <td>Bayraktar</td>
#       <td>28.0</td>
#       <td>4.0</td>
#       <td>0</td>
#       <td>5' 8"</td>
#       <td>155 lbs.</td>
#       <td>66"</td>
#       <td>Orthodox</td>
#       <td>2/1/1994</td>
#       <td>3.00</td>
#       <td>20%</td>
#       <td>5.67</td>
#       <td>46%</td>
#       <td>0.00</td>
#       <td>0%</td>
#       <td>66%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>david abbott</td>
#       <td>loss</td>
#       <td>Kevin Ferguson</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>EliteXC - Street Certified                                   Feb. 16, 2008</td>
#       <td>KO/TKO</td>
#       <td>1.0</td>
#       <td>1/1/2000</td>
#       <td>David</td>
#       <td>Abbott</td>
#       <td>http://ufcstats.com/fighter-details/b361180739bed4b0</td>
#       <td>Tank</td>
#       <td>10.0</td>
#       <td>15.0</td>
#       <td>0</td>
#       <td>6' 0"</td>
#       <td>265 lbs.</td>
#       <td>--</td>
#       <td>Switch</td>
#       <td>4/26/1965</td>
#       <td>1.35</td>
#       <td>30%</td>
#       <td>3.55</td>
#       <td>38%</td>
#       <td>1.07</td>
#       <td>33%</td>
#       <td>66%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>david abbott</td>
#       <td>loss</td>
#       <td>Paul Buentello</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>Strikeforce - Tank vs. Buentello                                   Oct. 07, 2006</td>
#       <td>KO/TKO</td>
#       <td>1.0</td>
#       <td>1/1/1995</td>
#       <td>David</td>
#       <td>Abbott</td>
#       <td>http://ufcstats.com/fighter-details/b361180739bed4b0</td>
#       <td>Tank</td>
#       <td>10.0</td>
#       <td>15.0</td>
#       <td>0</td>
#       <td>6' 0"</td>
#       <td>265 lbs.</td>
#       <td>--</td>
#       <td>Switch</td>
#       <td>4/26/1965</td>
#       <td>1.35</td>
#       <td>30%</td>
#       <td>3.55</td>
#       <td>38%</td>
#       <td>1.07</td>
#       <td>33%</td>
#       <td>66%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>david abbott</td>
#       <td>loss</td>
#       <td>Hidehiko Yoshida</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>PRIDE Final Conflict 2005                                   Aug. 28, 2005</td>
#       <td>SUB</td>
#       <td>1.0</td>
#       <td>1/1/2020</td>
#       <td>David</td>
#       <td>Abbott</td>
#       <td>http://ufcstats.com/fighter-details/b361180739bed4b0</td>
#       <td>Tank</td>
#       <td>10.0</td>
#       <td>15.0</td>
#       <td>0</td>
#       <td>6' 0"</td>
#       <td>265 lbs.</td>
#       <td>--</td>
#       <td>Switch</td>
#       <td>4/26/1965</td>
#       <td>1.35</td>
#       <td>30%</td>
#       <td>3.55</td>
#       <td>38%</td>
#       <td>1.07</td>
#       <td>33%</td>
#       <td>66%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>david abbott</td>
#       <td>loss</td>
#       <td>Wesley Correira</td>
#       <td>0</td>
#       <td>11</td>
#       <td>0</td>
#       <td>0</td>
#       <td>UFC 45: Revolution                                   Nov. 21, 2003</td>
#       <td>KO/TKO</td>
#       <td>1.0</td>
#       <td>1/1/2003</td>
#       <td>David</td>
#       <td>Abbott</td>
#       <td>http://ufcstats.com/fighter-details/b361180739bed4b0</td>
#       <td>Tank</td>
#       <td>10.0</td>
#       <td>15.0</td>
#       <td>0</td>
#       <td>6' 0"</td>
#       <td>265 lbs.</td>
#       <td>--</td>
#       <td>Switch</td>
#       <td>4/26/1965</td>
#       <td>1.35</td>
#       <td>30%</td>
#       <td>3.55</td>
#       <td>38%</td>
#       <td>1.07</td>
#       <td>33%</td>
#       <td>66%</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>david abbott</t

# %%
# Show columns to verify
print("Columns in dataset:", df.columns.tolist())
# Out:
# Columns in dataset: ['Fighter', 'W/L', 'Opponent', 'Knockdowns', 'Strikes', 'Takedowns', 'SubmissionAttempts', 'Event', 'Method', 'Round', 'Date', 'First Name', 'Last Name', 'Link', 'Nick Name', 'Wins', 'Losses', 'Draws', 'Height', 'Weight', 'Reach', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.']

# %% [markdown]
# # Distribution of Knockdowns

# %%
#1.Distribution of Knockdowns: Plot a histogram to see how often knockdowns occur

# Ensure Knockdowns column is numeric
df['Knockdowns'] = pd.to_numeric(df['Knockdowns'], errors='coerce')

# Determine max knockdowns
max_knockdowns = int(df['Knockdowns'].max())

# Create the plot
plt.figure(figsize=(5, 5))
ax = sns.histplot(data=df, x='Knockdowns', bins=range(0, max_knockdowns + 2), discrete=True, kde=True)

# Set labels and titles
plt.title('Knockdowns per UFC Fight (Distribution)', fontsize=14)
plt.xlabel('Number of Knockdowns', fontsize=12)
plt.ylabel('Number of Fights', fontsize=12)
plt.xlim(0, 3)

# Add value labels on bars
for patch in ax.patches:
    height = patch.get_height()
    if height > 0:
        ax.annotate(f'{int(height):,}',  # Adds commas for thousands
                    xy=(patch.get_x() + patch.get_width() / 2, height),
                    xytext=(0, 5),  # Increased offset for clarity
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold')

color= 'darkblue'


plt.tight_layout()
plt.show()

# %%
# Fixed extraction function
def safe_extract_strikes(strikes_str):
    if pd.isna(strikes_str) or str(strikes_str) == '--':
        return pd.Series([None, None])
    
    # Try the most common patterns
    match = re.search(r'(\d+).*?(\d+)', str(strikes_str))
    if match:
        return pd.Series([int(match.group(1)), int(match.group(2))])
    return pd.Series([None, None])

# Apply the extraction
df[['Strikes_Landed', 'Strikes_Attempted']] = df['Strikes'].apply(safe_extract_strikes)

# Check the results
print("Sample of extracted data:")
df[['Fighter', 'Strikes', 'Strikes_Landed', 'Strikes_Attempted']].head(10)
# Out:
# Sample of extracted data:
#            Fighter Strikes  Strikes_Landed  Strikes_Attempted
# 0        tom aaron      --             NaN                NaN
# 1        tom aaron      --             NaN                NaN
# 2     danny abbadi      56             5.0                6.0
# 3     danny abbadi       3             NaN                NaN
# 4  nariman abbasov      45             4.0                5.0
# 5     david abbott       1             NaN                NaN
# 6     david abbott       4             NaN                NaN
# 7     david abbott       2             NaN                NaN
# 8     david abbott      11             1.0                1.0
# 9     david abbott       0             NaN                NaN

# %%
# Check extraction success
successful = df['Strikes_Landed'].notna().sum()
print(f"\nSuccessful extractions: {successful} out of {len(df)}")

if successful > 0:
    print(f"Strikes_Landed range: {df['Strikes_Landed'].min()} to {df['Strikes_Landed'].max()}")
# Out:
# Successful extractions: 15842 out of 21508
# Strikes_Landed range: 1.0 to 44.0

# %%
# Remove the indentation - run this code directly
top_strikers = df.groupby('Fighter')['Strikes_Landed'].sum().sort_values(ascending=False).head(10)
print("Top 10 Fighters by Total Strikes Landed:")
print(top_strikers)
# Out:
# Top 10 Fighters by Total Strikes Landed:
# Fighter
# max holloway          333.0
# sean strickland       210.0
# angela hill           200.0
# king green            185.0
# donald cerrone        184.0
# nick diaz             174.0
# cub swanson           169.0
# joanna jedrzejczyk    169.0
# rafael dos anjos      168.0
# frankie edgar         168.0
# Name: Strikes_Landed, dtype: float64

# %%
# Check if we have meaningful data
if top_strikers.max() > 0:
    print(f"\nHighest total: {top_strikers.max()} strikes")
    print(f"Non-zero fighters: {(top_strikers > 0).sum()}")
# Out:
# Highest total: 333.0 strikes
# Non-zero fighters: 10

# %% [markdown]
# # 2. Top 10 Fighters by Total Strikes Landed

# %%
#2 Top 10 Fighters by Total Strikes Landed
plt.figure(figsize=(12, 8))

sns.barplot(x=top_strikers.values, y=top_strikers.index, color='#1f77b4', orient='h')

plt.title('Top 10 Fighters by Total Strikes Landed', fontsize=13, fontweight='bold')
plt.xlabel('Total Strikes Landed', fontsize=10)
plt.ylabel('Fighter', fontsize=10)

# Adding value labels
for i, v in enumerate(top_strikers.values):
    plt.text(v + max(top_strikers.values) * 0.01, i, f'{int(v)}', 
             va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Convert 'Weight' ('155 lbs.') to numeric (155)
# Clean the 'Weight' column
df['Weight_Clean'] = df['Weight'].str.extract(r'(\d+)').astype(float)

# %%
#Map to standard UFC divisions
weight_class_map = {
    115: 'Strawweight', 125: 'Flyweight', 135: 'Bantamweight',
    145: 'Featherweight', 155: 'Lightweight', 170: 'Welterweight',
    185: 'Middleweight', 205: 'Light Heavyweight', 265: 'Heavyweight'
}
df['Weight_Class'] = df['Weight_Clean'].map(weight_class_map)

# %%
#Drop rows where class couldn't be mapped
df = df.dropna(subset=['Weight_Class'])

# %%
#Estimate fight length (300 seconds = 5 minutes per round)
df = df[df['Round'].notna() & (df['Round'] > 0)].copy()
df['Fight_Seconds'] = df['Round'] * 300

# %%
# Group by weight class
avg_fight_length = df.groupby('Weight_Class')['Fight_Seconds'].mean().sort_values()

# %% [markdown]
# # 3. Average Fight Length by Weight Class

# %%
#3. Average Fight Length by Weight Class: Compare fight durations across division
plt.figure(figsize=(10, 6))

sns.barplot(x=avg_fight_length.values, y=avg_fight_length.index, color='#1f77b4') 
plt.title('Average Fight Length by Weight Class', fontsize=14, fontweight='bold')
plt.xlabel('Average Fight Length (seconds)', fontsize=11)
plt.ylabel('Weight Class', fontsize=11)

# Adding labels on bars
for i, v in enumerate(avg_fight_length.values):
    plt.text(v + 5, i, f'{int(v)}s', va='center')

plt.tight_layout()
plt.show()

# %%
#4. Win Method Trends: Create a pie chart or bar chart showing the proportion of wins by KO, submission, or decision.
def simplify_method(method):
    method = str(method).upper()  # Handle NaNs & lowercase
    if 'KO' in method:
        return 'KO/TKO'
    elif 'SUB' in method:
        return 'Submission'
    elif 'DEC' in method:
        return 'Decision'
    elif 'DQ' in method:
        return 'Disqualification'
    elif 'OVERTURNED' in method:
        return 'Overturned'
    else:
        return 'Other'

# %%
df['Win_Method_Simple'] = df['Method'].apply(simplify_method)
df['Win_Method_Simple']
# Out:
# 0          Decision
# 1        Submission
# 2          Decision
# 3        Submission
# 4          Decision
#             ...
# 21501      Decision
# 21502    Submission
# 21503    Submission
# 21504      Decision
# 21505      Decision
# Name: Win_Method_Simple, Length: 16694, dtype: object

# %%
#Count and sort
method_counts = df['Win_Method_Simple'].value_counts()
method_counts
# Out:
# Decision            7652
# KO/TKO              5338
# Submission          3470
# Overturned           110
# Other                 79
# Disqualification      45
# Name: Win_Method_Simple, dtype: int64

# %% [markdown]
# # 4. Win Method Trends

# %%
# Preview actual labels
print("Available win methods:", method_counts.index.tolist())
# Out:
# Available win methods: ['Decision', 'KO/TKO', 'Submission', 'Overturned', 'Other', 'Disqualification']

# %%
# Win Method Trends:
custom_order = ['Decision','Other','Submission', 'Overturned', 'KO/TKO', 'Disqualification']   
method_counts = method_counts[custom_order]

plt.figure(figsize=(8, 8))
colors = sns.color_palette('Set2', n_colors=len(method_counts))

method_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=100,
    colors=colors,
    textprops={'fontsize': 12},
    labeldistance=1.05
)

plt.ylabel('')
plt.title('Distribution of Win Methods', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Fight Frequency Over Time: Visualize how active fighters are across their careers.
# Check Date column
print(df['Date'].head())  # See the format of the date values
# Out:
# 0    7/12/2005
# 1    7/15/2009
# 2     1/1/1999
# 3     1/1/2012
# 4     1/1/2012
# Name: Date, dtype: object

# %%
#Convert to datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # 'coerce' will turn invalid dates into NaT
df['Date']
# Out:
# 0       2005-07-12
# 1       2009-07-15
# 2       1999-01-01
# 3       2012-01-01
# 4       2012-01-01
#            ...
# 21501   2020-01-01
# 21502   2003-01-01
# 21503   2003-01-01
# 21504   2022-01-01
# 21505   2009-01-01
# Name: Date, Length: 16694, dtype: datetime64[ns]

# %%
# Optional check: see if conversion worked
print("Sample converted dates:\n", df['Date'].dropna().head())
# Out:
# Sample converted dates:
#  0   2005-07-12
# 1   2009-07-15
# 2   1999-01-01
# 3   2012-01-01
# 4   2012-01-01
# Name: Date, dtype: datetime64[ns]

# %%
# STEP 2: Drop rows with missing dates
df_clean = df[df['Date'].notna()].copy()
df_clean
# Out:
#                Fighter   W/L        Opponent  Knockdowns Strikes Takedowns  \
# 0            tom aaron  loss  Matt Ricehouse         NaN      --        --
# 1            tom aaron   win  Eric Steenberg         NaN      --        --
# 2         danny abbadi  loss    Jorge Gurgel         0.0      56         0
# 3         danny abbadi  loss   Kalib Starnes         0.0       3         0
# 4      nariman abbasov  loss   Ismael Bonfim         0.0      45         0
# ...                ...   ...             ...         ...     ...       ...
# 21501      chris lytle  loss   Karo Parisyan         0.0     7\n       0\n
# 21502      chris lytle   win     Ronald Jhun         1.0    12\n       0\n
# 21503      chris lytle   win      Tiki Ghosn         0.0    34\n       2\n
# 21504      chris lytle  loss   Robbie Lawler         0.0    37\n       1\n
# 21505      chris lytle  loss     Ben Earwood         0.0     2\n       0\n
#
#       SubmissionAttempts                                              Event  \
# 0                     --  Strikeforce - Henderson vs. Babalu            ...
# 1                     --  Strikeforce - Heavy Artillery                 ...
# 2                      0  UFC 63: Hughes vs Penn                        ...
# 3                      0  The Ultimate Fighter: Team Ortiz vs. Team Sham...
# 4                      0  DWCS 6.7                                   Sep...
# ...                  ...                                                ...
# 21501                2\n  UFC 51: Super Saturday\n          \n\n\n      ...
# 21502                2\n  UFC 49: Unfinished Business\n          \n\n\n ...
# 21503                1\n  UFC 47: It's On!\n          \n\n\n          \n...
# 21504                1\n  UFC 45: Revolution\n          \n\n\n          ...
# 21505                1\n  UFC 28: High Stakes\n          \n\n\n         ...
#
#       Method  Round  ... TD Avg. TD Acc. TD Def. Sub. Avg. Strikes_Landed  \
# 0      U-DEC    3.0  ...     0.0      0%      0%       0.0            NaN
# 1        SUB    1.0  ...     0.0      0%      0%       0.0            NaN
# 2      S-DEC    3.0  ...     0.0      0%     77%       0.0            5.0
# 3        SUB    1.0  ...     0.0      0%     77%       0.0            NaN
# 4      U-DEC    3.0  ...     0.0      0%     66%       0.0            4.0
# ...      ...    ...  ...     ...     ...     ...       ...            ...
# 21501  U-DEC    3.0  ...     0.7     55%     55%       2.4            NaN
# 21502  SUB\n    2.0  ...     0.7     55%     55%       2.4            1.0
# 21503  SUB\n    2.0  ...     0.7     55%     55%       2.4            3.0
# 21504  U-DEC    3.0  ...     0.7     55%     55%       2.4            3.0
# 21505  U-DEC    2.0  ...     0.7     55%     55%       2.4            NaN
#
#        Strikes_Attempted  Weight_Clean  Weight_Class Fight_Seconds  \
# 0                    NaN         155.0   Lightweight         900.0
# 1                    NaN         155.0   Lightweight         300.0
# 2                    6.0         155.0   Lightweight         900.0
# 3                    NaN         155.0   Lightweight         300.0
# 4                    5.0         155.0   Lightweight         900.0
# ...                  ...           ...           ...           ...
# 21501                NaN         170.0  Welterweight         900.0
# 21502                2.0         170.0  Welterweight         600.0
# 21503                4.0         170.0  Welterweight         600.0
# 21504                7.0         170.0  Welterweight         900.0
# 21505                NaN         170.0  Welterweight         600.0
#
#       Win_Method_Simple
# 0              Decision
# 1            Submission
# 2              Decision
# 3            Submission
# 4              Decision
# ...                 ...
# 21501          Decision
# 21502        Submission
# 21503        Submission
# 21504          Decision
# 21505          Decision
#
# [16694 rows x 37 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0       2005-07-12
# 1       2009-07-15
# 2       1999-01-01
# 3       2012-01-01
# 4       2012-01-01
#            ...
# 21501   2020-01-01
# 21502   2003-01-01
# 21503   2003-01-01
# 21504   2022-01-01
# 21505   2009-01-01
# Name: Date, Length: 16694, dtype: datetime64[ns]

# %%
fights_per_year_count = df[df['Date'].dt.year >= 1998]['Date'].dt.year.value_counts().sort_index()
fights_per_year_count
# Out:
# 1998     935
# 1999     916
# 2000    1858
# 2001       4
# 2003    1847
# 2005     924
# 2009    1859
# 2012    1839
# 2020     915
# 2022     928
# 2023    1885
# 2024       4
# Name: Date, dtype: int64

# %%
fights_per_year_df = fights_per_year_count.reset_index()
fights_per_year_df.columns = ['Year', 'Fights']
fights_per_year_df.columns
# Out:
# Index(['Year', 'Fights'], dtype='object')

# %% [markdown]
# ## 5. Fight Frequency Over Time

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=fights_per_year_df, x='Year', y='Fights', marker='o', linewidth=2)
plt.title('Fight Frequency Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Fights', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
